# %% [markdown]
# <a href="https://colab.research.google.com/github/Tayeeba18/Data-Analysis/blob/main/LinkedIn_Data_Analysis_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loading dataset

import pandas as pd
lkd_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/LinkedIn/Connections.csv')

# %%
lkd_data.head(20)
# Out:
#            First Name                                      Last Name  \
# 0              Samiha                                          Yusuf
# 1   Mahatajin.Rumana.                                         Shuchi
# 2               Adham                                 Ibrahim Rahman
# 3              Rusafa                               Binte Sohrawardi
# 4              Bidyut                                       Sengupta
# 5                Khan                                     Farhana ❗️
# 6             Rakibul                                          Islam
# 7             Tanjila                                           Azad
# 8       Mostafa Musab                                         Naveed
# 9          MD. Tahmid                                         Rahman
# 10        Anwar Hasan                                          Shuvo
# 11        TAMIM HASAN                                          TURJO
# 12          Dr. Sabuj                                          Hasan
# ...

# %%
# size of the dataframe

lkd_data.shape
# Out:
# (541, 6)

# %%
lkd_data.drop(['Email Address'],axis=1,inplace=True)

# %%
lkd_data.head(20)
# Out:
#            First Name                                      Last Name  \
# 0              Samiha                                          Yusuf
# 1   Mahatajin.Rumana.                                         Shuchi
# 2               Adham                                 Ibrahim Rahman
# 3              Rusafa                               Binte Sohrawardi
# 4              Bidyut                                       Sengupta
# 5                Khan                                     Farhana ❗️
# 6             Rakibul                                          Islam
# 7             Tanjila                                           Azad
# 8       Mostafa Musab                                         Naveed
# 9          MD. Tahmid                                         Rahman
# 10        Anwar Hasan                                          Shuvo
# 11        TAMIM HASAN                                          TURJO
# 12          Dr. Sabuj                                          Hasan
# ...

# %% [markdown]
# # Connectivity Over Time

# %%
lkd_new = lkd_data.sort_values(by='Connected On')

import plotly.express as px

df=lkd_new.groupby(by='Connected On').count().reset_index()
px.line(df,
        x = 'Connected On',
        y = 'First Name',
        labels = {'First Name':'Number of Connections'},
        title = 'Connectivity Over Time')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Companies Of the Connections

# %%
lkd_new['Company']
# Out:
# 31                                   NaN
# 479                                  NaN
# 232                       Sarker Traders
# 233           SOLAR EPC DEVELOPMENT LTD.
# 168                            Freelance
#                      ...
# 171            ROBINTEX (BANGLADESH) LTD
# 172                           Quantanite
# 119                      STEMResearch.AI
# 315                          ACI Limited
# 314    Varna International  Plastics Co.
# Name: Company, Length: 541, dtype: object

# %%
company_variety = lkd_new.groupby(by='Company').count().reset_index()
company_variety
# Out:
#                        Company  First Name  Last Name  Position  Connected On
# 0               Kamil Madrasha           1          1         1             1
# 1             10 Minute School           2          2         2             2
# 2                2A IT Limited           1          1         1             1
# 3    AB Power Engineering Ltd.           1          1         1             1
# 4                      ABLC IT           1          1         1             1
# ..                         ...         ...        ...       ...           ...
# 356               iram traders           1          1         1             1
# 357                 myseven.io           1          1         1             1
# 358                     nimbus           1          1         1             1
# 359               মাটির পুতুল            1          1         1             1
# 360                 株式会社サグブレイン           1          1         1             1
#
# [361 rows x 5 columns]

# %%
# descending order
new_Com_variety=company_variety.sort_values(by='Connected On',ascending=False).reset_index(drop=True)

# %%
new_Com_variety
# Out:
#                        Company  First Name  Last Name  Position  Connected On
# 0              BRAC University          23         23        23            23
# 1                       Fiverr           8          8         8             8
# 2                    Freelance           5          5         5             5
# 3                bKash Limited           4          4         4             4
# 4                      BRAC IT           4          4         4             4
# ..                         ...         ...        ...       ...           ...
# 356             Freelancer.com           1          1         1             1
# 357  Freelance (Self employed)           1          1         1             1
# 358     Fly Far International            1          1         1             1
# 359      Flora Telecom Limited           1          1         1             1
# 360                 株式会社サグブレイン           1          1         1             1
#
# [361 rows x 5 columns]

# %%
# Visualization

fig = px.bar(company_variety[:200],
       x = 'Company',
       y = 'Connected On',
       labels = {'Connected On':'Number of Connections'},
       width = 1200,
       height = 900,
       title = 'Companies Connections Work At')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 # Tree Plot for same data
fig2 = px.treemap(company_variety[:200],path=['Company','Position'], 
       values = 'Connected On',
       labels = {'Connected On':'Number of Connections'},
       width = 1500,
       height = 850,
       title = 'Companies Connections Work At')
fig2
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Positions of the Connections

# %%
lkd_new['Position'].value_counts()
# Out:
# Lecturer                                  11
# Intern                                     7
# Software Engineer                          5
# Executive                                  5
# Research Assistant                         5
#                                           ..
# Manager at Krishibid seed limited          1
# Human Resources Team Lead                  1
# Founder and CEO                            1
# Proprietor                                 1
# Information Technology Support Officer     1
# Name: Position, Length: 340, dtype: int64

# %%
lkd_new['Position'].value_counts()/len(lkd_new)*100>0.20
# Out:
# Lecturer                                   True
# Intern                                     True
# Software Engineer                          True
# Executive                                  True
# Research Assistant                         True
#                                           ...
# Manager at Krishibid seed limited         False
# Human Resources Team Lead                 False
# Founder and CEO                           False
# Proprietor                                False
# Information Technology Support Officer    False
# Name: Position, Length: 340, dtype: bool

# %%
lkd_new['Position'].value_counts()[lkd_new['Position'].value_counts()/len(lkd_new)*100>0.50]
# Out:
# Lecturer                            11
# Intern                               7
# Software Engineer                    5
# Executive                            5
# Research Assistant                   5
# Student Tutor                        4
# Founder                              4
# Campus Ambassador                    4
# Assistant Manager                    4
# Graphic Designer                     4
# Chief Executive Officer              4
# Marketing Executive                  4
# Senior Executive Human Resources     3
# Manager                              3
# Human Resources Executive            3
# Professional Freelancer              3
# Business Development Executive       3
# Digital Marketing Specialist         3
# Co-Founder                           3
# Senior Executive                     3
# Name: Position, dtype: int64

# %%
 # position visualization

fig3 = px.bar(lkd_new.groupby(by='Position').count().sort_values(by='First Name',ascending=False)[:50].reset_index(), 
       x = 'Position',  
       y = 'Connected On',
       labels = {'Connected On':'Number of Connections'}, 
       width = 1500,
       height = 850,
       title = 'Positions My Connections Work At')
fig3
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # WordCloud Visualization

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

def CreateWordCloud(text):
  wordcloud = WordCloud(width=1000,height=900,
                        background_color='black',
                        min_font_size= 10,
                        colormap = 'Set2').generate(text)

  fig5 = plt.figure(figsize=(15,10))
  plt.imshow(wordcloud,interpolation = 'bilinear')

  plt.show()
  return fig5

# %%
positions = ' '.join(lkd_new[~lkd_new.Position.isnull()].Position.unique())

# %%
CreateWordCloud(positions)
